# %% [markdown]
# # Execution du modèle

# %%
from SparseMLP import SparseMLP
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from test_pytorch import SparseMLP
#
# ModuleNotFoundError: No module named 'test_pytorch'

# %% [markdown]
# ### Import du modèle

# %%
model = SparseMLP(input_dim=input_dim, hidden_dim=1000, output_dim=1, sparsity=0.8)
model.load_state_dict(torch.load("modele_sparsemlp.pth", map_location=torch.device('cpu')))
model.eval()
print("Modèle chargé avec succès")
